# %%
pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp39-cp39-win_amd64.whl (96 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2022.12.7 charset-normalizer-3.0.1 idna-3.4 requests-2.28.2 urllib3-1.26.14
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\chief\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.1.3; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Users\chief\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import pandas as db

# %%
respuesta_servicio = requests.get( "https://api.bitso.com/v3/trades/?book=btc_mxn" )
json_respuesta = respuesta_servicio.json()

# %%
json_respuesta
# Out:
# {'success': True,
#  'payload': [{'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:44+0000',
#    'amount': '0.00090013',
#    'maker_side': 'sell',
#    'price': '451770',
#    'tid': 90113861},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:44+0000',
#    'amount': '0.00003955',
#    'maker_side': 'sell',
#    'price': '451770',
#    'tid': 90113858},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:42+0000',
#    'amount': '0.00037629',
#    'maker_side': 'sell',
#    'price': '451780',
#    'tid': 90113856},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:20+0000',
#    'amount': '0.01204495',
#    'maker_side': 'buy',
#    'price': '451670',
#    'tid': 90113842},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:12+0000',
#    'amount': '0.00044260',
#    'maker_side': 'sell',
#    'price': '451880',
#    'tid': 90113836},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:17:03+0000',
#    'amount': '0.00814001',
#    'maker_side': 'buy',
#    'price': '451630',
#    'tid': 90113831},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:47+0000',
#    'amount': '0.00000851',
#    'maker_side': 'buy',
#    'price': '451590',
#    'tid': 90113820},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:47+0000',
#    'amount': '0.00002435',
#    'maker_side': 'buy',
#    'price': '451690',
#    'tid': 90113819},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:11+0000',
#    'amount': '0.01137359',
#    'maker_side': 'sell',
#    'price': '452100',
#    'tid': 90113807},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:09+0000',
#    'amount': '0.02211900',
#    'maker_side': 'sell',
#    'price': '452100',
#    'tid': 90113803},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:08+0000',
#    'amount': '0.00008848',
#    'maker_side': 'sell',
#    'price': '452100',
#    'tid': 90113802},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:16:03+0000',
#    'amount': '0.00044527',
#    'maker_side': 'buy',
#    'price': '451700',
#    'tid': 90113799},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:15:30+0000',
#    'amount': '0.05706937',
#    'maker_side': 'buy',
#    'price': '451810',
#    'tid': 90113783},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:15:23+0000',
#    'amount': '0.02312272',
#    'maker_side': 'buy',
#    'price': '451940',
#    'tid': 90113780},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:15:23+0000',
#    'amount': '0.01540000',
#    'maker_side': 'buy',
#    'price': '451950',
#    'tid': 90113779},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:15:13+0000',
#    'amount': '0.01564420',
#    'maker_side': 'buy',
#    'price': '452130',
#    'tid': 90113775},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:14:28+0000',
#    'amount': '0.00088972',
#    'maker_side': 'buy',
#    'price': '452120',
#    'tid': 90113742},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:14:15+0000',
#    'amount': '0.00449182',
#    'maker_side': 'buy',
#    'price': '452080',
#    'tid': 90113734},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:12:36+0000',
#    'amount': '0.00021495',
#    'maker_side': 'buy',
#    'price': '452110',
#    'tid': 90113683},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:12:33+0000',
#    'amount': '0.01848300',
#    'maker_side': 'buy',
#    'price': '452110',
#    'tid': 90113680},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:12:02+0000',
#    'amount': '0.00011051',
#    'maker_side': 'sell',
#    'price': '452450',
#    'tid': 90113665},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:11:47+0000',
#    'amount': '0.00006836',
#    'maker_side': 'sell',
#    'price': '452450',
#    'tid': 90113660},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:11:46+0000',
#    'amount': '0.00203393',
#    'maker_side': 'buy',
#    'price': '452000',
#    'tid': 90113658},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:11:43+0000',
#    'amount': '0.00298376',
#    'maker_side': 'sell',
#    'price': '452450',
#    'tid': 90113655},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:10:34+0000',
#    'amount': '0.22115087',
#    'maker_side': 'sell',
#    'price': '452180',
#    'tid': 90113598},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:10:21+0000',
#    'amount': '0.00442331',
#    'maker_side': 'sell',
#    'price': '452150',
#    'tid': 90113573},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:10:12+0000',
#    'amount': '0.04158464',
#    'maker_side': 'sell',
#    'price': '452090',
#    'tid': 90113560},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:09:36+0000',
#    'amount': '0.02481421',
#    'maker_side': 'sell',
#    'price': '451830',
#    'tid': 90113529},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:08:32+0000',
#    'amount': '0.00081600',
#    'maker_side': 'buy',
#    'price': '451540',
#    'tid': 90113484},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:50+0000',
#    'amount': '0.00222865',
#    'maker_side': 'buy',
#    'price': '451240',
#    'tid': 90113457},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:46+0000',
#    'amount': '0.00408288',
#    'maker_side': 'buy',
#    'price': '451240',
#    'tid': 90113450},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:23+0000',
#    'amount': '0.00460394',
#    'maker_side': 'buy',
#    'price': '451400',
#    'tid': 90113444},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:22+0000',
#    'amount': '0.00415428',
#    'maker_side': 'buy',
#    'price': '451410',
#    'tid': 90113443},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:13+0000',
#    'amount': '0.02054572',
#    'maker_side': 'buy',
#    'price': '451410',
#    'tid': 90113441},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:07:04+0000',
#    'amount': '0.00111489',
#    'maker_side': 'buy',
#    'price': '451410',
#    'tid': 90113435},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:06:59+0000',
#    'amount': '0.00235095',
#    'maker_side': 'buy',
#    'price': '451410',
#    'tid': 90113433},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:06:37+0000',
#    'amount': '0.00664216',
#    'maker_side': 'sell',
#    'price': '451660',
#    'tid': 90113422},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:06:26+0000',
#    'amount': '0.00000357',
#    'maker_side': 'buy',
#    'price': '451500',
#    'tid': 90113418},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:06:08+0000',
#    'amount': '0.00774919',
#    'maker_side': 'sell',
#    'price': '451660',
#    'tid': 90113410},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:05:57+0000',
#    'amount': '0.00309968',
#    'maker_side': 'sell',
#    'price': '451660',
#    'tid': 90113407},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:05:44+0000',
#    'amount': '0.00132843',
#    'maker_side': 'sell',
#    'price': '451660',
#    'tid': 90113403},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:05:18+0000',
#    'amount': '0.03938061',
#    'maker_side': 'buy',
#    'price': '451500',
#    'tid': 90113395},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:04:57+0000',
#    'amount': '0.00221401',
#    'maker_side': 'sell',
#    'price': '451670',
#    'tid': 90113375},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:04:53+0000',
#    'amount': '0.00112444',
#    'maker_side': 'buy',
#    'price': '451440',
#    'tid': 90113372},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:04:48+0000',
#    'amount': '0.00000897',
#    'maker_side': 'sell',
#    'price': '451670',
#    'tid': 90113369},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:04:47+0000',
#    'amount': '0.00442801',
#    'maker_side': 'sell',
#    'price': '451670',
#    'tid': 90113367},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:04:22+0000',
#    'amount': '0.01113610',
#    'maker_side': 'buy',
#    'price': '451420',
#    'tid': 90113350},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:42+0000',
#    'amount': '0.01392190',
#    'maker_side': 'buy',
#    'price': '451420',
#    'tid': 90113336},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:41+0000',
#    'amount': '0.00008532',
#    'maker_side': 'buy',
#    'price': '451420',
#    'tid': 90113331},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:34+0000',
#    'amount': '0.00899607',
#    'maker_side': 'buy',
#    'price': '451420',
#    'tid': 90113329},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:22+0000',
#    'amount': '0.15770283',
#    'maker_side': 'sell',
#    'price': '451740',
#    'tid': 90113316},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:22+0000',
#    'amount': '0.23054290',
#    'maker_side': 'sell',
#    'price': '451620',
#    'tid': 90113315},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:03:22+0000',
#    'amount': '0.02580000',
#    'maker_side': 'sell',
#    'price': '451610',
#    'tid': 90113314},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:02:58+0000',
#    'amount': '0.03188451',
#    'maker_side': 'sell',
#    'price': '451630',
#    'tid': 90113293},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:02:27+0000',
#    'amount': '0.02286752',
#    'maker_side': 'buy',
#    'price': '451400',
#    'tid': 90113264},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:02:27+0000',
#    'amount': '0.01179250',
#    'maker_side': 'buy',
#    'price': '451450',
#    'tid': 90113263},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:02:23+0000',
#    'amount': '0.00044270',
#    'maker_side': 'sell',
#    'price': '451770',
#    'tid': 90113262},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:01:44+0000',
#    'amount': '0.02213222',
#    'maker_side': 'sell',
#    'price': '451830',
#    'tid': 90113249},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:01:22+0000',
#    'amount': '0.00044364',
#    'maker_side': 'sell',
#    'price': '451830',
#    'tid': 90113222},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:01:13+0000',
#    'amount': '0.02038320',
#    'maker_side': 'buy',
#    'price': '451650',
#    'tid': 90113218},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:01:12+0000',
#    'amount': '0.00003541',
#    'maker_side': 'sell',
#    'price': '451890',
#    'tid': 90113217},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:01:04+0000',
#    'amount': '0.00002213',
#    'maker_side': 'sell',
#    'price': '451890',
#    'tid': 90113212},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:00:18+0000',
#    'amount': '0.00724625',
#    'maker_side': 'sell',
#    'price': '452070',
#    'tid': 90113186},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:00:06+0000',
#    'amount': '0.00150495',
#    'maker_side': 'buy',
#    'price': '451910',
#    'tid': 90113173},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:00:05+0000',
#    'amount': '0.00102069',
#    'maker_side': 'buy',
#    'price': '451930',
#    'tid': 90113172},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:00:03+0000',
#    'amount': '0.23392070',
#    'maker_side': 'sell',
#    'price': '452080',
#    'tid': 90113169},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T22:00:02+0000',
#    'amount': '0.23392230',
#    'maker_side': 'buy',
#    'price': '452080',
#    'tid': 90113167},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:59:40+0000',
#    'amount': '0.00168520',
#    'maker_side': 'buy',
#    'price': '451810',
#    'tid': 90113144},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:43+0000',
#    'amount': '0.00003434',
#    'maker_side': 'buy',
#    'price': '451540',
#    'tid': 90113118},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:35+0000',
#    'amount': '0.00110719',
#    'maker_side': 'buy',
#    'price': '451600',
#    'tid': 90113115},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:24+0000',
#    'amount': '0.04580960',
#    'maker_side': 'sell',
#    'price': '451590',
#    'tid': 90113112},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:23+0000',
#    'amount': '0.10054430',
#    'maker_side': 'sell',
#    'price': '451590',
#    'tid': 90113111},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:22+0000',
#    'amount': '0.10054430',
#    'maker_side': 'sell',
#    'price': '451590',
#    'tid': 90113110},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:22+0000',
#    'amount': '0.15310180',
#    'maker_side': 'sell',
#    'price': '451590',
#    'tid': 90113109},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:21+0000',
#    'amount': '0.01235220',
#    'maker_side': 'sell',
#    'price': '451600',
#    'tid': 90113108},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:21+0000',
#    'amount': '0.00090000',
#    'maker_side': 'sell',
#    'price': '451590',
#    'tid': 90113107},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:21+0000',
#    'amount': '0.01201720',
#    'maker_side': 'sell',
#    'price': '451620',
#    'tid': 90113106},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:20+0000',
#    'amount': '0.00684730',
#    'maker_side': 'sell',
#    'price': '451620',
#    'tid': 90113105},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:20+0000',
#    'amount': '0.01185480',
#    'maker_side': 'sell',
#    'price': '451640',
#    'tid': 90113104},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:19+0000',
#    'amount': '0.10435069',
#    'maker_side': 'buy',
#    'price': '451550',
#    'tid': 90113101},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:19+0000',
#    'amount': '0.01201720',
#    'maker_side': 'buy',
#    'price': '451630',
#    'tid': 90113100},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:13+0000',
#    'amount': '0.00066000',
#    'maker_side': 'buy',
#    'price': '451650',
#    'tid': 90113094},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:58:11+0000',
#    'amount': '0.00377000',
#    'maker_side': 'buy',
#    'price': '451650',
#    'tid': 90113090},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:40+0000',
#    'amount': '0.00079150',
#    'maker_side': 'buy',
#    'price': '451630',
#    'tid': 90113077},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:33+0000',
#    'amount': '0.03304688',
#    'maker_side': 'buy',
#    'price': '451610',
#    'tid': 90113075},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:28+0000',
#    'amount': '0.00802836',
#    'maker_side': 'buy',
#    'price': '451540',
#    'tid': 90113073},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:25+0000',
#    'amount': '0.00170664',
#    'maker_side': 'buy',
#    'price': '451570',
#    'tid': 90113068},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:10+0000',
#    'amount': '0.02422050',
#    'maker_side': 'buy',
#    'price': '451450',
#    'tid': 90113062},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:57:04+0000',
#    'amount': '0.22278499',
#    'maker_side': 'buy',
#    'price': '451530',
#    'tid': 90113056},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:56:26+0000',
#    'amount': '0.00332123',
#    'maker_side': 'sell',
#    'price': '451640',
#    'tid': 90113027},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:56:07+0000',
#    'amount': '0.00004428',
#    'maker_side': 'sell',
#    'price': '451650',
#    'tid': 90113018},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:55:51+0000',
#    'amount': '0.02590559',
#    'maker_side': 'sell',
#    'price': '451640',
#    'tid': 90113011},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:55:41+0000',
#    'amount': '0.00022141',
#    'maker_side': 'sell',
#    'price': '451650',
#    'tid': 90113004},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:55:34+0000',
#    'amount': '0.02745626',
#    'maker_side': 'buy',
#    'price': '451400',
#    'tid': 90113000},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:54:49+0000',
#    'amount': '0.00120346',
#    'maker_side': 'sell',
#    'price': '451640',
#    'tid': 90112979},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:54:40+0000',
#    'amount': '0.00513293',
#    'maker_side': 'sell',
#    'price': '451520',
#    'tid': 90112974},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:54:34+0000',
#    'amount': '0.00010609',
#    'maker_side': 'sell',
#    'price': '451520',
#    'tid': 90112969},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:52:54+0000',
#    'amount': '0.00017729',
#    'maker_side': 'sell',
#    'price': '451240',
#    'tid': 90112897},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:52:32+0000',
#    'amount': '0.00221607',
#    'maker_side': 'sell',
#    'price': '451250',
#    'tid': 90112886},
#   {'book': 'btc_mxn',
#    'created_at': '2023-02-19T21:51:40+0000',
#    'amount': '0.01548895',
#    'maker_side': 'sell',
#    'price': '451390',
#    'tid': 90112853}]}

# %%
BTCMXN_bitso = json_respuesta[ "payload" ]

# %%
BTCMXN_bitso
# Out:
# [{'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:44+0000',
#   'amount': '0.00090013',
#   'maker_side': 'sell',
#   'price': '451770',
#   'tid': 90113861},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:44+0000',
#   'amount': '0.00003955',
#   'maker_side': 'sell',
#   'price': '451770',
#   'tid': 90113858},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:42+0000',
#   'amount': '0.00037629',
#   'maker_side': 'sell',
#   'price': '451780',
#   'tid': 90113856},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:20+0000',
#   'amount': '0.01204495',
#   'maker_side': 'buy',
#   'price': '451670',
#   'tid': 90113842},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:12+0000',
#   'amount': '0.00044260',
#   'maker_side': 'sell',
#   'price': '451880',
#   'tid': 90113836},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:17:03+0000',
#   'amount': '0.00814001',
#   'maker_side': 'buy',
#   'price': '451630',
#   'tid': 90113831},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:47+0000',
#   'amount': '0.00000851',
#   'maker_side': 'buy',
#   'price': '451590',
#   'tid': 90113820},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:47+0000',
#   'amount': '0.00002435',
#   'maker_side': 'buy',
#   'price': '451690',
#   'tid': 90113819},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:11+0000',
#   'amount': '0.01137359',
#   'maker_side': 'sell',
#   'price': '452100',
#   'tid': 90113807},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:09+0000',
#   'amount': '0.02211900',
#   'maker_side': 'sell',
#   'price': '452100',
#   'tid': 90113803},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:08+0000',
#   'amount': '0.00008848',
#   'maker_side': 'sell',
#   'price': '452100',
#   'tid': 90113802},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:16:03+0000',
#   'amount': '0.00044527',
#   'maker_side': 'buy',
#   'price': '451700',
#   'tid': 90113799},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:15:30+0000',
#   'amount': '0.05706937',
#   'maker_side': 'buy',
#   'price': '451810',
#   'tid': 90113783},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:15:23+0000',
#   'amount': '0.02312272',
#   'maker_side': 'buy',
#   'price': '451940',
#   'tid': 90113780},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:15:23+0000',
#   'amount': '0.01540000',
#   'maker_side': 'buy',
#   'price': '451950',
#   'tid': 90113779},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:15:13+0000',
#   'amount': '0.01564420',
#   'maker_side': 'buy',
#   'price': '452130',
#   'tid': 90113775},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:14:28+0000',
#   'amount': '0.00088972',
#   'maker_side': 'buy',
#   'price': '452120',
#   'tid': 90113742},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:14:15+0000',
#   'amount': '0.00449182',
#   'maker_side': 'buy',
#   'price': '452080',
#   'tid': 90113734},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:12:36+0000',
#   'amount': '0.00021495',
#   'maker_side': 'buy',
#   'price': '452110',
#   'tid': 90113683},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:12:33+0000',
#   'amount': '0.01848300',
#   'maker_side': 'buy',
#   'price': '452110',
#   'tid': 90113680},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:12:02+0000',
#   'amount': '0.00011051',
#   'maker_side': 'sell',
#   'price': '452450',
#   'tid': 90113665},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:11:47+0000',
#   'amount': '0.00006836',
#   'maker_side': 'sell',
#   'price': '452450',
#   'tid': 90113660},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:11:46+0000',
#   'amount': '0.00203393',
#   'maker_side': 'buy',
#   'price': '452000',
#   'tid': 90113658},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:11:43+0000',
#   'amount': '0.00298376',
#   'maker_side': 'sell',
#   'price': '452450',
#   'tid': 90113655},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:10:34+0000',
#   'amount': '0.22115087',
#   'maker_side': 'sell',
#   'price': '452180',
#   'tid': 90113598},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:10:21+0000',
#   'amount': '0.00442331',
#   'maker_side': 'sell',
#   'price': '452150',
#   'tid': 90113573},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:10:12+0000',
#   'amount': '0.04158464',
#   'maker_side': 'sell',
#   'price': '452090',
#   'tid': 90113560},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:09:36+0000',
#   'amount': '0.02481421',
#   'maker_side': 'sell',
#   'price': '451830',
#   'tid': 90113529},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:08:32+0000',
#   'amount': '0.00081600',
#   'maker_side': 'buy',
#   'price': '451540',
#   'tid': 90113484},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:50+0000',
#   'amount': '0.00222865',
#   'maker_side': 'buy',
#   'price': '451240',
#   'tid': 90113457},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:46+0000',
#   'amount': '0.00408288',
#   'maker_side': 'buy',
#   'price': '451240',
#   'tid': 90113450},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:23+0000',
#   'amount': '0.00460394',
#   'maker_side': 'buy',
#   'price': '451400',
#   'tid': 90113444},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:22+0000',
#   'amount': '0.00415428',
#   'maker_side': 'buy',
#   'price': '451410',
#   'tid': 90113443},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:13+0000',
#   'amount': '0.02054572',
#   'maker_side': 'buy',
#   'price': '451410',
#   'tid': 90113441},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:07:04+0000',
#   'amount': '0.00111489',
#   'maker_side': 'buy',
#   'price': '451410',
#   'tid': 90113435},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:06:59+0000',
#   'amount': '0.00235095',
#   'maker_side': 'buy',
#   'price': '451410',
#   'tid': 90113433},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:06:37+0000',
#   'amount': '0.00664216',
#   'maker_side': 'sell',
#   'price': '451660',
#   'tid': 90113422},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:06:26+0000',
#   'amount': '0.00000357',
#   'maker_side': 'buy',
#   'price': '451500',
#   'tid': 90113418},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:06:08+0000',
#   'amount': '0.00774919',
#   'maker_side': 'sell',
#   'price': '451660',
#   'tid': 90113410},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:05:57+0000',
#   'amount': '0.00309968',
#   'maker_side': 'sell',
#   'price': '451660',
#   'tid': 90113407},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:05:44+0000',
#   'amount': '0.00132843',
#   'maker_side': 'sell',
#   'price': '451660',
#   'tid': 90113403},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:05:18+0000',
#   'amount': '0.03938061',
#   'maker_side': 'buy',
#   'price': '451500',
#   'tid': 90113395},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:04:57+0000',
#   'amount': '0.00221401',
#   'maker_side': 'sell',
#   'price': '451670',
#   'tid': 90113375},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:04:53+0000',
#   'amount': '0.00112444',
#   'maker_side': 'buy',
#   'price': '451440',
#   'tid': 90113372},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:04:48+0000',
#   'amount': '0.00000897',
#   'maker_side': 'sell',
#   'price': '451670',
#   'tid': 90113369},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:04:47+0000',
#   'amount': '0.00442801',
#   'maker_side': 'sell',
#   'price': '451670',
#   'tid': 90113367},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:04:22+0000',
#   'amount': '0.01113610',
#   'maker_side': 'buy',
#   'price': '451420',
#   'tid': 90113350},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:42+0000',
#   'amount': '0.01392190',
#   'maker_side': 'buy',
#   'price': '451420',
#   'tid': 90113336},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:41+0000',
#   'amount': '0.00008532',
#   'maker_side': 'buy',
#   'price': '451420',
#   'tid': 90113331},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:34+0000',
#   'amount': '0.00899607',
#   'maker_side': 'buy',
#   'price': '451420',
#   'tid': 90113329},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:22+0000',
#   'amount': '0.15770283',
#   'maker_side': 'sell',
#   'price': '451740',
#   'tid': 90113316},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:22+0000',
#   'amount': '0.23054290',
#   'maker_side': 'sell',
#   'price': '451620',
#   'tid': 90113315},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:03:22+0000',
#   'amount': '0.02580000',
#   'maker_side': 'sell',
#   'price': '451610',
#   'tid': 90113314},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:02:58+0000',
#   'amount': '0.03188451',
#   'maker_side': 'sell',
#   'price': '451630',
#   'tid': 90113293},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:02:27+0000',
#   'amount': '0.02286752',
#   'maker_side': 'buy',
#   'price': '451400',
#   'tid': 90113264},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:02:27+0000',
#   'amount': '0.01179250',
#   'maker_side': 'buy',
#   'price': '451450',
#   'tid': 90113263},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:02:23+0000',
#   'amount': '0.00044270',
#   'maker_side': 'sell',
#   'price': '451770',
#   'tid': 90113262},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:01:44+0000',
#   'amount': '0.02213222',
#   'maker_side': 'sell',
#   'price': '451830',
#   'tid': 90113249},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:01:22+0000',
#   'amount': '0.00044364',
#   'maker_side': 'sell',
#   'price': '451830',
#   'tid': 90113222},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:01:13+0000',
#   'amount': '0.02038320',
#   'maker_side': 'buy',
#   'price': '451650',
#   'tid': 90113218},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:01:12+0000',
#   'amount': '0.00003541',
#   'maker_side': 'sell',
#   'price': '451890',
#   'tid': 90113217},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:01:04+0000',
#   'amount': '0.00002213',
#   'maker_side': 'sell',
#   'price': '451890',
#   'tid': 90113212},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:00:18+0000',
#   'amount': '0.00724625',
#   'maker_side': 'sell',
#   'price': '452070',
#   'tid': 90113186},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:00:06+0000',
#   'amount': '0.00150495',
#   'maker_side': 'buy',
#   'price': '451910',
#   'tid': 90113173},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:00:05+0000',
#   'amount': '0.00102069',
#   'maker_side': 'buy',
#   'price': '451930',
#   'tid': 90113172},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:00:03+0000',
#   'amount': '0.23392070',
#   'maker_side': 'sell',
#   'price': '452080',
#   'tid': 90113169},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T22:00:02+0000',
#   'amount': '0.23392230',
#   'maker_side': 'buy',
#   'price': '452080',
#   'tid': 90113167},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:59:40+0000',
#   'amount': '0.00168520',
#   'maker_side': 'buy',
#   'price': '451810',
#   'tid': 90113144},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:43+0000',
#   'amount': '0.00003434',
#   'maker_side': 'buy',
#   'price': '451540',
#   'tid': 90113118},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:35+0000',
#   'amount': '0.00110719',
#   'maker_side': 'buy',
#   'price': '451600',
#   'tid': 90113115},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:24+0000',
#   'amount': '0.04580960',
#   'maker_side': 'sell',
#   'price': '451590',
#   'tid': 90113112},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:23+0000',
#   'amount': '0.10054430',
#   'maker_side': 'sell',
#   'price': '451590',
#   'tid': 90113111},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:22+0000',
#   'amount': '0.10054430',
#   'maker_side': 'sell',
#   'price': '451590',
#   'tid': 90113110},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:22+0000',
#   'amount': '0.15310180',
#   'maker_side': 'sell',
#   'price': '451590',
#   'tid': 90113109},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:21+0000',
#   'amount': '0.01235220',
#   'maker_side': 'sell',
#   'price': '451600',
#   'tid': 90113108},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:21+0000',
#   'amount': '0.00090000',
#   'maker_side': 'sell',
#   'price': '451590',
#   'tid': 90113107},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:21+0000',
#   'amount': '0.01201720',
#   'maker_side': 'sell',
#   'price': '451620',
#   'tid': 90113106},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:20+0000',
#   'amount': '0.00684730',
#   'maker_side': 'sell',
#   'price': '451620',
#   'tid': 90113105},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:20+0000',
#   'amount': '0.01185480',
#   'maker_side': 'sell',
#   'price': '451640',
#   'tid': 90113104},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:19+0000',
#   'amount': '0.10435069',
#   'maker_side': 'buy',
#   'price': '451550',
#   'tid': 90113101},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:19+0000',
#   'amount': '0.01201720',
#   'maker_side': 'buy',
#   'price': '451630',
#   'tid': 90113100},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:13+0000',
#   'amount': '0.00066000',
#   'maker_side': 'buy',
#   'price': '451650',
#   'tid': 90113094},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:58:11+0000',
#   'amount': '0.00377000',
#   'maker_side': 'buy',
#   'price': '451650',
#   'tid': 90113090},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:40+0000',
#   'amount': '0.00079150',
#   'maker_side': 'buy',
#   'price': '451630',
#   'tid': 90113077},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:33+0000',
#   'amount': '0.03304688',
#   'maker_side': 'buy',
#   'price': '451610',
#   'tid': 90113075},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:28+0000',
#   'amount': '0.00802836',
#   'maker_side': 'buy',
#   'price': '451540',
#   'tid': 90113073},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:25+0000',
#   'amount': '0.00170664',
#   'maker_side': 'buy',
#   'price': '451570',
#   'tid': 90113068},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:10+0000',
#   'amount': '0.02422050',
#   'maker_side': 'buy',
#   'price': '451450',
#   'tid': 90113062},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:57:04+0000',
#   'amount': '0.22278499',
#   'maker_side': 'buy',
#   'price': '451530',
#   'tid': 90113056},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:56:26+0000',
#   'amount': '0.00332123',
#   'maker_side': 'sell',
#   'price': '451640',
#   'tid': 90113027},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:56:07+0000',
#   'amount': '0.00004428',
#   'maker_side': 'sell',
#   'price': '451650',
#   'tid': 90113018},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:55:51+0000',
#   'amount': '0.02590559',
#   'maker_side': 'sell',
#   'price': '451640',
#   'tid': 90113011},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:55:41+0000',
#   'amount': '0.00022141',
#   'maker_side': 'sell',
#   'price': '451650',
#   'tid': 90113004},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:55:34+0000',
#   'amount': '0.02745626',
#   'maker_side': 'buy',
#   'price': '451400',
#   'tid': 90113000},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:54:49+0000',
#   'amount': '0.00120346',
#   'maker_side': 'sell',
#   'price': '451640',
#   'tid': 90112979},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:54:40+0000',
#   'amount': '0.00513293',
#   'maker_side': 'sell',
#   'price': '451520',
#   'tid': 90112974},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:54:34+0000',
#   'amount': '0.00010609',
#   'maker_side': 'sell',
#   'price': '451520',
#   'tid': 90112969},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:52:54+0000',
#   'amount': '0.00017729',
#   'maker_side': 'sell',
#   'price': '451240',
#   'tid': 90112897},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:52:32+0000',
#   'amount': '0.00221607',
#   'maker_side': 'sell',
#   'price': '451250',
#   'tid': 90112886},
#  {'book': 'btc_mxn',
#   'created_at': '2023-02-19T21:51:40+0000',
#   'amount': '0.01548895',
#   'maker_side': 'sell',
#   'price': '451390',
#   'tid': 90112853}]

# %%
grid_BTCMXN_bitso = db.DataFrame( BTCMXN_bitso )

# %%
grid_BTCMXN_bitso
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 grid_BTCMXN_bitso
#
# NameError: name 'grid_BTCMXN_bitso' is not defined

# %%
grid_BTCMXN_bitso.to_csv( "Datos19012023.CSV", index = False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 grid_BTCMXN_bitso.to_csv( "Datos19012023.CSV", index = False )
#
# NameError: name 'grid_BTCMXN_bitso' is not defined
